# %% [markdown]
# <a href="https://colab.research.google.com/github/brainmentorspvtltd/IGDTU_PyTorchTraining/blob/main/IG_ChestXRAY_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["KAGGLE_USERNAME"] = "ravikanttyagi"
os.environ["KAGGLE_KEY"] = "25515d47526c5940215de7a00cc56fc8"

# !kaggle datasets download paultimothymooney/chest-xray-pneumonia
# Out:
# ...
# 100% 2.29G/2.29G [00:26<00:00, 106MB/s]
# 100% 2.29G/2.29G [00:26<00:00, 92.7MB/s]

# %%
# !unzip chest-xray-pneumonia.zip

# %%
len(os.listdir("chest_xray/train/NORMAL"))
# Out:
# 1341

# %%
len(os.listdir("chest_xray/train/PNEUMONIA"))
# Out:
# 3875

# %%
import cv2
import matplotlib.pyplot as plt

# %%
path = "chest_xray/train/PNEUMONIA/person1000_bacteria_2931.jpeg"
img = cv2.imread(path)

# %%
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (760, 1152, 3)
